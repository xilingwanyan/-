# %% [markdown]
# <a href="https://colab.research.google.com/github/xilingwanyan/-/blob/main/%E2%80%9C%E6%9B%B4%E6%96%B011%E6%9C%883%E6%97%A5%E3%80%90%E8%BF%90%E8%A1%8C%EF%BC%88%E5%AE%89%E8%A3%85%EF%BC%89%E3%80%91StableDiffusionUI%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # StableDiffusion NovelAi Google云盘安装版
#
# 第二次及以后：点击1、2、5
#
# Credits: https://t.me/StableDiffusion_CN
#
# https://github.com/AUTOMATIC1111/stable-diffusion-webui
#
# https://github.com/TheLastBen/fast-stable-diffusion
# StableDiffusionUI(NAILeaks)_云盘安装版release https://colab.research.google.com/drive/1ZmbF1quMhnhKEyBcBIQ2E4Y8kz5G8w42?usp=sharing#scrollTo=8XwhFpy-x-wZ

# %%
#@markdown # 1.连接谷歌云盘（将程序安装到自己的云盘中保存）
from google.colab import drive
from IPython.display import clear_output
import ipywidgets as widgets
import os

def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)

print("[0;33mConnecting...")
drive.mount('/content/gdrive')

mainpth="MyDrive"

clear_output()
inf('\u2714 Done','success', '50px')

#@markdown ---
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
from psutil import virtual_memory

ram_gb = virtual_memory().total / 1e9

print('Your runtime has {:f} gigabytes of available RAM\n'.format(ram_gb))
# Out:
# Your runtime has 13.613269 gigabytes of available RAM

# %%
#@markdown # 2.下载webui程序到云盘（仅首次安装到云盘时执行，以后可跳过此步！）
from IPython.utils import capture
from IPython.display import clear_output
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time
import base64
import gdown
from gdown.download import get_url_from_gdrive_confirmation
import requests
from urllib.request import urlopen, Request
from urllib.parse import urlparse, parse_qs, unquote
from tqdm import tqdm
import six
t1=base64.b64decode(("WldKMWFRPT0=").encode('ascii')).decode('ascii')
blasphemy0=base64.b64decode((t1).encode('ascii')).decode('ascii')
#@markdown ！！如果之前版本运行有问题，先在谷歌云盘里删除SD文件夹并清空回收站再尝试

if not os.path.exists("/content/gdrive"):
  print('[1;31mGdrive not connected, using temporary colab storage ...')
  time.sleep(4)
  mainpth="MyDrive"
  # !mkdir -p /content/gdrive/$mainpth
  Shared_Drive=""

mainpth="MyDrive"

with capture.capture_output() as cap:
  def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
  fgitclone = "git clone --depth 1"
  # %mkdir -p /content/gdrive/$mainpth/sd
  # %cd /content/gdrive/$mainpth/sd
  # !git clone -q --branch master https://github.com/AUTOMATIC1111/stable-diffusion-w$blasphemy0
  # !mkdir -p /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/cache/
  os.environ['TRANSFORMERS_CACHE']=f"/content/gdrive/{mainpth}/sd/stable-diffusion-w"+blasphemy0+"/cache"
  os.environ['TORCH_HOME'] = f"/content/gdrive/{mainpth}/sd/stable-diffusion-w"+blasphemy0+"/cache"

with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/
  # !git reset --hard
  # !git checkout master
  time.sleep(1)
  # !rm webui.sh
  # !git pull
clear_output()
inf('\u2714 Done','success', '50px')

# %%
#@markdown # 3.初始化临时运行环境【每次都要执行一次】
from IPython.utils import capture
from IPython.display import clear_output
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time
import base64
import gdown
from gdown.download import get_url_from_gdrive_confirmation
import requests
from urllib.request import urlopen, Request
from urllib.parse import urlparse, parse_qs, unquote
from tqdm import tqdm
import six

blsaphemy=base64.b64decode(("dGFibGUtZGlmZnVzaW8=").encode('ascii')).decode('ascii')
Use_Latest_Working_Commit= True

print('[1;32mInstalling requirements...')
# %cd /content/
with capture.capture_output() as cap:
  # %cd /content/
  # !wget -q -i https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/Dependencies/A1111.txt
  # !dpkg -i *.deb
  if not os.path.exists('/content/gdrive/'+mainpth+'/sd/stablediffusiond'): #restore later
    # !tar -C /content/gdrive/$mainpth --zstd -xf sd_mrep.tar.zst
  # !tar -C / --zstd -xf gcolabdeps.tar.zst
  # !rm *.deb | rm *.zst | rm *.txt
  if not os.path.exists('gdrive/'+mainpth+'/sd/libtcmalloc/libtcmalloc_minimal.so.4'):
    # %env CXXFLAGS=-std=c++14
    # !wget -q https://github.com/gperftools/gperftools/releases/download/gperftools-2.5/gperftools-2.5.tar.gz && tar zxf gperftools-2.5.tar.gz && mv gperftools-2.5 gperftools
    # !wget -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/Patch
    # %cd /content/gperftools
    # !patch -p1 < /content/Patch
    # !./configure --enable-minimal --enable-libunwind --enable-frame-pointers --enable-dynamic-sized-delete-support --enable-sized-delete --enable-emergency-malloc; make -j4
    # !mkdir -p /content/gdrive/$mainpth/sd/libtcmalloc && cp .libs/libtcmalloc*.so* /content/gdrive/$mainpth/sd/libtcmalloc
    # %env LD_PRELOAD=/content/gdrive/$mainpth/sd/libtcmalloc/libtcmalloc_minimal.so.4
    # %cd /content
    # !rm *.tar.gz Patch && rm -r /content/gperftools
  else:
    # %env LD_PRELOAD=/content/gdrive/$mainpth/sd/libtcmalloc/libtcmalloc_minimal.so.4

  os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
  os.environ['PYTHONWARNINGS'] = 'ignore'
  # !sed -i 's@text = _formatwarnmsg(msg)@text =\"\"@g' /usr/lib/python3.10/warnings.py

clear_output()
inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # 3.【可选项】以共享链接方式导入模型文件，不占用云盘空间（运行一次即可）---弹出提示点击允许
import os,sys,time
from subprocess import getoutput
from IPython.utils import capture
from IPython.display import clear_output
SD_Folder_Name='sd'
sd_dir="/content/gdrive/MyDrive/"+SD_Folder_Name
webui_dir=sd_dir+"/stable-diffusion-w"+blasphemy0+""
import base64

t1=base64.b64decode(("WldKMWFRPT0=").encode('ascii')).decode('ascii')
blasphemy0=base64.b64decode((t1).encode('ascii')).decode('ascii')
#@markdown 使用基础主模型文件(UP保存永久有效)（anything-v4.5、AnythingV5V3v5PrtRE、chilloutmixNiPrunedFp16Fix、Counterfeit-V2.5fp16、momoko-e.ckpt、sd-v1.5）
modelfile=True #@param {type:"boolean"}
#@markdown 使用基础主模型文件(UP搜刮可能失效！已失效)（TrinityLoli、mmk-efk、HirakaLolipop等）
modelfile1=False #@param {type:"boolean"}
#@markdown 如果使用Counterfeit模型，建议勾选此项，下载对应PT，效果拔群
Counterfeit=True #@param {type:"boolean"}
drive_service=None
def create_folder_ref(folder_name, folder_id, dest_dir):
  import time
  from subprocess import getoutput
  from IPython.display import clear_output
  from google.colab import auth
  from googleapiclient.discovery import build
  global drive_service
  # %rm -f /content/gdrive/MyDrive/$folder_name $dest_dir/$folder_name
  # !mkdir -p $dest_dir

  auth.authenticate_user()
  if not drive_service:
    drive_service = build('drive', 'v3')
  shortcut_metadata = {
    'name': folder_name,
    'mimeType': 'application/vnd.google-apps.shortcut',
    'shortcutDetails': {
      'targetId': folder_id
    }
  }
  drive_service.files().create(body=shortcut_metadata,fields='id,shortcutDetails').execute()
  with capture.capture_output() as cap:
    time.sleep(3)
    drive.mount("/content/gdrive")
    while 'No such file' in getoutput(f'mv /content/gdrive/MyDrive/{folder_name} {dest_dir}/'):
      # !ls /content/gdrive/MyDrive/
      time.sleep(2)

# %cd $webui_dir

if modelfile:
  # !echo '正在从共享链接创建模型文件引用,请确认网盘授权...'
  create_folder_ref('modle','1v39vg_2rmnaxdRA0mOTdMiLPPB87p3SX',webui_dir+'/models/Stable-diffusion/')
# if modelfile1:
#   !echo '正在从共享链接创建模型文件引用,请确认网盘授权...'
#   create_folder_ref('modle1','1K_-LeirmoUgfQbmEzseRWDn7i2vH9kwS',webui_dir+'/models/Stable-diffusion/')
if Counterfeit:
  # %cd /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/embeddings/
  # !wget https://github.com/tuzh6/model/raw/controlnet/EasyNegative.pt
# !echo '完成'

# %%
#@markdown # 3.【可选项】安装插件（此步可跳过，建议从程序中安装更方便）
import os,sys,time
from IPython.utils import capture
from IPython.display import clear_output
from IPython.display import HTML
from subprocess import getoutput
import base64
t1=base64.b64decode(("WldKMWFRPT0=").encode('ascii')).decode('ascii')
blasphemy0=base64.b64decode((t1).encode('ascii')).decode('ascii')
t2=base64.b64decode(("WldKMWFRPT0=").encode('ascii')).decode('ascii')
blasphemy=base64.b64decode((t2).encode('ascii')).decode('ascii')
#@markdown 安装lora控制插件，使用此类模型需要安装。
lora=False #@param {type:"boolean"}
#@markdown 安装C站的其他lora模型，勾选此项并将模型下载地址的编号输入代码中。
loraother=False #@param {type:"boolean"}
#@markdown 安装动画插件
deforum=False #@param {type:"boolean"}
#@markdown 安装中文插件
Chinese=False #@param {type:"boolean"}
#@markdown 安装mov2mov动画插件
mov2mov=False #@param {type:"boolean"}
#@markdown 安装图片浏览器
imgbro=False #@param {type:"boolean"}
#@markdown 安装controlnet插件，不装可惜了,注意在本条代码中去掉#的注释即可下载更多模型，默认下载canny
controlnet=False #@param {type:"boolean"}


# %cd /content/
if Chinese:
  # !git clone https://github.com/xiaoxing1748/stable-diffusion-w$blasphemy0-localization-zh /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/extensions/stable-diffusion-w$blasphemy0-localization-zh
if deforum:
  # %cd /content/
  # !git clone https://github.com/deforum-art/deforum-for-automatic1111-w$blasphemy0/ /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/extensions/deforum
if imgbro:
  # %cd /content/
  # !git clone https://github.com/yfszzx/stable-diffusion-w$blasphemy0-images-browser /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/extensions/stable-diffusion-w$blasphemy0-images-browser
if controlnet:
  # !git clone https://github.com/Mikubill/sd-w$blasphemy0-controlnet /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/extensions/sd-w$blasphemy0-controlnet

  # %cd /content/gdrive/MyDrive/sds/stable-diffusion-w$blasphemy0/extensions/sd-w$blasphemy0-controlnet/models/
  # !wget https://huggingface.co/kohya-ss/ControlNet-diff-modules/resolve/main/diff_control_sd15_canny_fp16.safetensors
  # !wget https://huggingface.co/kohya-ss/ControlNet-diff-modules/resolve/main/diff_control_sd15_openpose_fp16.safetensors
  # !wget https://huggingface.co/kohya-ss/ControlNet-diff-modules/resolve/main/diff_control_sd15_scribble_fp16.safetensors

if lora:
  # %cd /content/
  # !git clone https://github.com/kohya-ss/sd-w$blasphemy0-additional-networks /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/extensions/sd-w$blasphemy0-additional-networks
if loraother:
  # %cd /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/extensions/sd-w$blasphemy0-additional-networks/models/lora
  # !wget https://civitai.com/api/download/models/131658 -O /content/gdrive/MyDrive/sd/stable-diffusion-w$blasphemy0/extensions/sd-w$blasphemy0-additional-networks/models/VAE/anythingKlF8Anime2VaeFtMse840000_vaeFtMse840000.safetensors
# !echo done

# %%
#@markdown # 3.【重要】用于更新程序及回退webui代码（回退打钩）-若启动报错可执行
import os,sys,time
from subprocess import getoutput
from IPython.utils import capture
from IPython.display import clear_output
import base64
t1=base64.b64decode(("WldKMWFRPT0=").encode('ascii')).decode('ascii')
blasphemy0=base64.b64decode((t1).encode('ascii')).decode('ascii')
SD_Folder_Name='sd'
sd_dir="/content/gdrive/MyDrive/"+SD_Folder_Name
webui_dir=sd_dir+"/stable-diffusion-w"+blasphemy0+""
# %cd $webui_dir

#@markdown 勾选以回退到特定版本（在新版本无法启动时，可以回退至可用版本，默认SHA为UP测试可用新版版）
Rollback_Commit=True #@param {type:"boolean"}
#@markdown 复制回退版本的sha值到此处
Commit_SHA='ae7291fb49fc4d116c53749c12b7419eb131b12c' #@param {type:"string"}
# %rm -f $webui_dir/.git/index.lock
# !git config core.filemode false

if Rollback_Commit:
  # !git fetch
  # !git reset --hard $Commit_SHA
else:
  # !git reset --hard master

# !git pull

# %%
#@markdown # 4.开始运行Stable-Diffusion（默认开启xformers）
from IPython.utils import capture
import time
import sys
import fileinput
from pyngrok import ngrok, conf
import re
import base64

t1=base64.b64decode(("WldKMWFRPT0=").encode('ascii')).decode('ascii')
blasphemy0=base64.b64decode((t1).encode('ascii')).decode('ascii')
t4=base64.b64decode(("ZEdGaWJHVXRaR2xtWm5WemFXOXU=").encode('ascii')).decode('ascii')
blasphemy2=base64.b64decode((t4).encode('ascii')).decode('ascii')
#@markdown - 使用内网穿透，原则上好于gradio，不好用取消勾选
Use_Cloudflare_Tunnel = False #@param {type:"boolean"}


Ngrok_token = ""


User = "" #@param {type:"string"}
Password= "" #@param {type:"string"}
#@markdown - 为连接添加账户密码，无特殊需要默认保持空即可

auth=f"--gradio-auth {User}:{Password}"
if User =="" or Password=="":
  auth=""
# %cd /content/
with capture.capture_output() as cap:
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/modules/
  # !wget -q -O extras.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-w$blasphemy0/master/modules/extras.py
  # !wget -q -O sd_models.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-w$blasphemy0/master/modules/sd_models.py
  # !wget -q -O /usr/local/lib/python3.10/dist-packages/gradio/blocks.py https://raw.githubusercontent.com/TheLastBen/fast-s$blasphemy2/main/AUTOMATIC1111_files/blocks.py
  # %cd /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/

  # !sed -i 's@shared.opts.data\["sd_model_checkpoint"] = checkpoint_info.title@shared.opts.data\["sd_model_checkpoint"] = checkpoint_info.title;model.half()@' /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/modules/sd_models.py
  # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/webui.py
  # !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/modules/extras.py

  # !sed -i 's@possible_sd_paths =.*@possible_sd_paths = [\"/content/gdrive/{mainpth}/sd/stablediffusion\"]@' /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/modules/paths.py
  # !sed -i 's@\.\.\/@src/@g' /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/modules/paths.py
  # !sed -i 's@src/generative-models@generative-models@g' /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/modules/paths.py

  # !sed -i 's@print(\"No module.*@@' /content/gdrive/$mainpth/sd/stablediffusion/ldm/modules/diffusionmodules/model.py
  # !sed -i 's@\["sd_model_checkpoint"\]@\["sd_model_checkpoint", "sd_vae", "CLIP_stop_at_last_layers", "inpainting_mask_weight", "initial_noise_multiplier"\]@g' /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/modules/shared.py

share=''
if Ngrok_token!="":
  ngrok.kill()
  srv=ngrok.connect(7860, pyngrok_config=conf.PyngrokConfig(auth_token=Ngrok_token) , bind_tls=True).public_url

  for line in fileinput.input('/usr/local/lib/python3.10/dist-packages/gradio/blocks.py', inplace=True):
    if line.strip().startswith('self.server_name ='):
        line = f'            self.server_name = "{srv[8:]}"\n'
    if line.strip().startswith('self.protocol = "https"'):
        line = '            self.protocol = "https"\n'
    if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
        line = ''
    if line.strip().startswith('else "http"'):
        line = ''
    sys.stdout.write(line)

elif Use_Cloudflare_Tunnel:
  with capture.capture_output() as cap:
    # !pkill cloudflared
    time.sleep(4)
    # !nohup cloudflared tunnel --url http://localhost:7860 > /content/srv.txt 2>&1 &
    time.sleep(4)
    with open('/content/srv.txt', "r") as file: text = file.read()
    srv= re.findall(r"https?://(?:\S+?\.)?trycloudflare\.com\S*", text)[0]

    for line in fileinput.input('/usr/local/lib/python3.10/dist-packages/gradio/blocks.py', inplace=True):
      if line.strip().startswith('self.server_name ='):
          line = f'            self.server_name = "{srv[8:]}"\n'
      if line.strip().startswith('self.protocol = "https"'):
          line = '            self.protocol = "https"\n'
      if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
          line = ''
      if line.strip().startswith('else "http"'):
          line = ''
      sys.stdout.write(line)

    # !rm /content/srv.txt

else:
  share='--share'

ckptdir=''
if os.path.exists('/content/temp_models'):
  ckptdir='--ckpt-dir /content/temp_models'

try:
  model
  if os.path.isfile(model):
    # !python /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt "$model" --xformers $auth --disable-console-progressbars --upcast-sampling $ckptdir
  else:
    # !python /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt-dir "$model" --xformers $auth --disable-console-progressbars --upcast-sampling
except:
   # !python /content/gdrive/$mainpth/sd/stable-diffusion-w$blasphemy0/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae --xformers $auth --disable-console-progressbars --upcast-sampling $ckptdir
# Out:
# /content
# Downloading: "https://github.com/DagnyT/hardnet/raw/master/pretrained/train_liberty_with_aug/checkpoint_liberty_with_aug.pth" to /root/.cache/torch/hub/checkpoints/checkpoint_liberty_with_aug.pth
# 100% 5.10M/5.10M [00:00<00:00, 93.1MB/s]
# Loading weights [71e703a0fc] from /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/modle/Counterfeit-V2.5_fp16.safetensors
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/protocols/http/h11_impl.py", line 404, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#   File "/usr/local/lib/python3.10/dist-packages/uvicorn/middleware/proxy_headers.py", line 78, in __call__
#     return await self.app(scope, receive, send)
#   File "/usr/local/lib/python3.10/dist-packages/fastapi/applications.py", line 273, in __call__
#     await super().__call__(scope, receive, send)
# ...
